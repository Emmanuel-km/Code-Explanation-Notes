# %% [markdown]
# There is a concern on NaN value

# %% [markdown]
# we can drop the nan row by use of dropna()

# %%
import pandas as pd
df=pd.read_csv('homeData.csv')
df
# Out:
#                  time  dhi_pyr  ghi_pyr_1  ghi_pyr_2  air_temperature  \
# 0      4/12/2019 0:01      0.0        0.0        0.0        15.598166
# 1      4/12/2019 0:02      0.0        0.0        0.0        15.573500
# 2      4/12/2019 0:03      0.0        0.0        0.0        15.566666
# 3      4/12/2019 0:04      0.0        0.0        0.0        15.556666
# 4      4/12/2019 0:05      0.0        0.0        0.0        15.532499
# ...               ...      ...        ...        ...              ...
# 1434  4/12/2019 23:55      0.0        0.0        0.0        16.480665
# 1435  4/12/2019 23:56      0.0        0.0        0.0        16.467333
# 1436  4/12/2019 23:57      0.0        0.0        0.0        16.447332
# 1437  4/12/2019 23:58      0.0        0.0        0.0        16.432333
# 1438  4/12/2019 23:59      0.0        0.0        0.0        16.418999
#
#       relative_humidity  barometric_pressure  precipitation  wind_speed  \
# ...

# %% [markdown]
# before droping the na value categories
# The dataset was 1439 rows × 14 columns

# %%
df.dropna(inplace=True)
df
# Out:
#                  time  dhi_pyr  ghi_pyr_1  ghi_pyr_2  air_temperature  \
# 0      4/12/2019 0:01      0.0        0.0        0.0        15.598166
# 1      4/12/2019 0:02      0.0        0.0        0.0        15.573500
# 2      4/12/2019 0:03      0.0        0.0        0.0        15.566666
# 3      4/12/2019 0:04      0.0        0.0        0.0        15.556666
# 4      4/12/2019 0:05      0.0        0.0        0.0        15.532499
# ...               ...      ...        ...        ...              ...
# 1434  4/12/2019 23:55      0.0        0.0        0.0        16.480665
# 1435  4/12/2019 23:56      0.0        0.0        0.0        16.467333
# 1436  4/12/2019 23:57      0.0        0.0        0.0        16.447332
# 1437  4/12/2019 23:58      0.0        0.0        0.0        16.432333
# 1438  4/12/2019 23:59      0.0        0.0        0.0        16.418999
#
#       relative_humidity  barometric_pressure  precipitation  wind_speed  \
# ...

# %% [markdown]
# now after droping the na values:
# the data set is at 1437 rows × 14 columns
#  from 1439 rows × 14 columns
