# %% [markdown]
# to process some of the data types in csv
# or any other the data type should be changed

# %% [markdown]
# for example in homeData.csv file the time column is in string formart as shown below

# %%
import pandas as pd


df=pd.read_csv('homeData.csv')
print(type(df.time[0]))
# Out:
# <class 'str'>

# %% [markdown]
# so to solve this issue we will convert the time column as date/time

# %%
df=pd.read_csv('homeData.csv',parse_dates=['time'])
print(type(df.time[0]))
df.set_index('time',inplace=True)
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# successful created

# %%
df
# Out:
#                      dhi_pyr  ghi_pyr_1  ghi_pyr_2  air_temperature  \
# time
# 2019-04-12 00:01:00      0.0        0.0        0.0        15.598166
# 2019-04-12 00:02:00      0.0        0.0        0.0        15.573500
# 2019-04-12 00:03:00      0.0        0.0        0.0        15.566666
# 2019-04-12 00:04:00      0.0        0.0        0.0        15.556666
# 2019-04-12 00:05:00      0.0        0.0        0.0        15.532499
# ...                      ...        ...        ...              ...
# 2019-04-12 23:55:00      0.0        0.0        0.0        16.480665
# 2019-04-12 23:56:00      0.0        0.0        0.0        16.467333
# 2019-04-12 23:57:00      0.0        0.0        0.0        16.447332
# 2019-04-12 23:58:00      0.0        0.0        0.0        16.432333
# 2019-04-12 23:59:00      0.0        0.0        0.0        16.418999
#
#                      relative_humidity  barometric_pressure  precipitation  \
# time
# ...
