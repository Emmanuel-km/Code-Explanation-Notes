# %%
'''
importing numpy
setting up a dataframe
indexing the time colomn as the index

'''

import pandas as pd

df=pd.read_csv('homeData.csv')

try:
    df=df.set_index('time')
    print("succeded")
except: 
    print("an error occcured")
# Out:
# succeded

# %%
k=df.iloc[59:119]
k
#k.describe()
# Out:
#                 dhi_pyr  ghi_pyr_1  ghi_pyr_2  air_temperature  \
# time
# 4/12/2019 1:00      0.0        0.0        0.0        15.600000
# 4/12/2019 1:01      0.0        0.0        0.0        15.585833
# 4/12/2019 1:02      0.0        0.0        0.0        15.556833
# 4/12/2019 1:03      0.0        0.0        0.0        15.548333
# 4/12/2019 1:04      0.0        0.0        0.0        15.553165
# 4/12/2019 1:05      0.0        0.0        0.0        15.556499
# 4/12/2019 1:06      0.0        0.0        0.0        15.566666
# 4/12/2019 1:07      0.0        0.0        0.0        15.566500
# 4/12/2019 1:08      0.0        0.0        0.0        15.579000
# 4/12/2019 1:09      0.0        0.0        0.0        15.585833
# 4/12/2019 1:10      0.0        0.0        0.0        15.606666
# 4/12/2019 1:11      0.0        0.0        0.0        15.623166
# 4/12/2019 1:12      0.0        0.0        0.0        15.599667
# 4/12/2019 1:13      0.0        0.0        0.0        15.585833
# ...

# %%
import pandas as pd

df=pd.read_csv('homeData.csv')
df=df.set_index('time')

k=df[['air_temperature','relative_humidity','wind_from_direction']]
k=k.loc['4/12/2019 2:00':'4/12/2019 2:15']
k

#df.loc['4/12/2019 1:00':'4/12/2019 1:59',df[['air_temperature','relative_humidity','wind_from_direction']]]
# Out:
#                 air_temperature  relative_humidity  wind_from_direction
# time
# 4/12/2019 2:00        15.533999          97.280998           207.815628
# 4/12/2019 2:01        15.518332          97.225998           203.877106
# 4/12/2019 2:02        15.505666          97.225998           206.563995
# 4/12/2019 2:03        15.518332          97.176002           208.857071
# 4/12/2019 2:04        15.509334          97.225998           203.122330
# 4/12/2019 2:05        15.519667          97.230003           203.516892
# 4/12/2019 2:06        15.505666          97.225998           200.528717
# 4/12/2019 2:07        15.516333          97.255997           199.157776
# 4/12/2019 2:08        15.511000          97.222000           199.704559
# 4/12/2019 2:09        15.500667          97.277000           198.654343
# 4/12/2019 2:10        15.513000          97.328003           204.891693
# 4/12/2019 2:11        15.501666          97.273003           197.578690
# ...

# %%
p=k.describe()
p
# Out:
#        air_temperature  relative_humidity  wind_from_direction
# count        16.000000          16.000000            16.000000
# mean         15.511916          97.247437           202.158539
# std           0.009167           0.036896             3.964251
# min          15.500667          97.176002           194.867294
# 25%          15.504749          97.225998           199.031918
# 50%          15.512000          97.230003           203.304947
# 75%          15.518332          97.278000           204.158493
# max          15.533999          97.328003           208.857071

# %%
y=p.mean()
print(y)
print(type(y))
# Out:
# air_temperature         19.186877
# relative_humidity       80.221208
# wind_from_direction    156.348064
# dtype: float64
# <class 'pandas.core.series.Series'>
