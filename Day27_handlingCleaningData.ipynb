# %%
import pandas as pd

df= pd.read_csv('homeData.csv')

df.fillna(0,inplace=True)

mean=df['barometric_pressure'].mean()
print(f"the mean for barometric_pressure is {mean}")

max=df['barometric_pressure'].max()
print(f"the maximum value for barometric_pressure is {max}")


min=df['barometric_pressure'].min()
print(f"the minimum barometric_pressure measure is {min}")
# Out:
# the mean for barometric_pressure is 809.429202442043
# the maximum value for barometric_pressure is 812.3051147
# the minimum barometric_pressure measure is 0.0

# %%
df.describe()
# Out:
#            dhi_pyr    ghi_pyr_1    ghi_pyr_2  air_temperature  \
# count  1439.000000  1439.000000  1439.000000      1439.000000
# mean    146.946761   249.055541   249.114990        17.860171
# std     203.660265   370.866940   371.725332         2.722965
# min       0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000        15.556750
# 50%       0.805126     1.741604     1.412038        16.944166
# 75%     304.127701   528.153625   526.179962        19.648166
# max     667.205322  1401.639038  1417.180908        23.996332
#
#        relative_humidity  barometric_pressure  precipitation   wind_speed  \
# count        1439.000000          1439.000000    1439.000000  1439.000000
# mean           85.813332           809.429202       0.003336     2.013625
# std            13.818773            30.227564       0.025621     0.905616
# min             0.000000             0.000000       0.000000     0.000000
# ...

# %%
df[df.air_temperature>23.4]
# Out:
#                 time     dhi_pyr    ghi_pyr_1    ghi_pyr_2  air_temperature  \
# 825  4/12/2019 13:46  316.624145  1279.078613  1287.592407        23.996332
# 826  4/12/2019 13:47  313.369659  1220.421875  1224.779785        23.678833
# 827  4/12/2019 13:48  320.598755  1137.417358  1140.077637        23.479666
# 828  4/12/2019 13:49  363.270447   789.322205   783.812439        23.494999
# 916  4/12/2019 15:17  220.944626   895.118042   902.910400        23.412832
#
#      relative_humidity  barometric_pressure  precipitation  wind_speed  \
# 825          54.160000           809.434937            0.0    2.633667
# 826          60.791000           809.441711            0.0    1.035650
# 827          61.865002           809.422729            0.0    2.207000
# 828          59.275002           809.398193            0.0    3.820333
# 916          63.716999           808.384460            0.0    4.260333
#
#      wind_from_direction    gti_clean     gti_soil  gti_monthly  \
# ...

# %%
#printing out specific columns

y=df[df.air_temperature>23.4]

y[['time','air_temperature','relative_humidity']]
# Out:
#                 time  air_temperature  relative_humidity
# 825  4/12/2019 13:46        23.996332          54.160000
# 826  4/12/2019 13:47        23.678833          60.791000
# 827  4/12/2019 13:48        23.479666          61.865002
# 828  4/12/2019 13:49        23.494999          59.275002
# 916  4/12/2019 15:17        23.412832          63.716999
