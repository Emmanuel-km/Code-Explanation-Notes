# %% [markdown]
# over the past recent years, artificial intelligence has developed masssively this is by training large data set models by already existing ones. <br>
# In this era AI, is a machine language model that performs querys, analysis and work flow of already existing ones so one has not to struggle as hard.<br>
# It is like what you need you get with just a few wording unlike the traditional google way where you have to focus on keyword terms.<br>
