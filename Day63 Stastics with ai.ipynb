# %% [markdown]
# over the past recent years, artificial intelligence has developed masssively this is by training large data set models by already existing ones. <br>
# In this era AI, is a machine language model that performs querys, analysis and work flow of already existing ones so one has not to struggle as hard.<br>
# It is like what you need you get with just a few wording unlike the traditional google way where you have to focus on keyword terms.<br>

# %% [markdown]
# Developers, scientist have an easy and a pretty good exponation curve of laearning.<br>
# So the question is, will ai take data analyst jobs and data scientist ocupation.<br>
# The answer is **Yes and NO** at the same time.<br>
# I can accompany this with the computer era (2000-2012), computers replaced all the middle men involved in sending letters<br>
# But they had to replace the jobs with more efficient such as someone operating a computer.<br>
# We are in an age where its either you learn ai or someone who knows ai will replace you.<br>

# %% [markdown]
# The role of data scientist,analyst need to be combined into one category so that one person perticipates in all data related woks.<br>
# This means one has to learn a vast amount of knowledge of how things are to get to know what the structure and logic of the experience looks like before handing data projects with the code<br>
# The job that took a team of five will be handled by one person <br>
# How to get ahead, just learn everyday a new subset to add to your skills and take ai courses
